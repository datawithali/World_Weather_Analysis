# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 771

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | boa vista
# Processing Record 5 of Set 1 | kastamonu
# Processing Record 6 of Set 1 | oranjestad
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | khash
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | dawlatabad
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | ziro
# Processing Record 13 of Set 1 | shalya
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | ostrovnoy
# Processing Record 16 of Set 1 | smithers
# Processing Record 17 of Set 1 | leninskoye
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | itoman
# Processing Record 20 of Set 1 | cabo san lucas
# Processing Record 21 of Set 1 | kulachi
# Processing Record 22 of Set 1 | gizo
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | meulaboh
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | tonj
# Processing Record 29 of Set 1 | vardo
# Processing Record 30 of Set 1 | lethem
# Processing Record 31 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 1 | sao felix do xingu
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | koundara
# Processing Record 38 of Set 1 | xining
# Processing Record 39 of Set 1 | mount isa
# Processing Record 40 of Set 1 | constantine
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 1 | narsaq
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | vilyuysk
# Processing Record 50 of Set 1 | pueblo nuevo
# Processing Record 1 of Set 2 | prieska
# Processing Record 2 of Set 2 | klyuchi
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | mahibadhoo
# Processing Record 5 of Set 2 | pasighat
# Processing Record 6 of Set 2 | carballo
# Processing Record 7 of Set 2 | saint anthony
# Processing Record 8 of Set 2 | iqaluit
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | northallerton
# Processing Record 11 of Set 2 | rafai
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | campbellton
# Processing Record 14 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | tigil
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | ewa beach
# Processing Record 20 of Set 2 | port hedland
# Processing Record 21 of Set 2 | xiaoweizhai
# Processing Record 22 of Set 2 | chernyshevskiy
# Processing Record 23 of Set 2 | provideniya
# Processing Record 24 of Set 2 | arinos
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | sitka
# Processing Record 27 of Set 2 | pemangkat
# Processing Record 28 of Set 2 | port blair
# Processing Record 29 of Set 2 | port hardy
# Processing Record 30 of Set 2 | ahipara
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | bagn
# Processing Record 34 of Set 2 | hofn
# Processing Record 35 of Set 2 | pahrump
# Processing Record 36 of Set 2 | berlevag
# Processing Record 37 of Set 2 | anuchino
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | atambua
# Processing Record 40 of Set 2 | kieta
# Processing Record 41 of Set 2 | bambous virieux
# Processing Record 42 of Set 2 | lensk
# Processing Record 43 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 2 | perpignan
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | andenes
# Processing Record 47 of Set 2 | yambio
# Processing Record 48 of Set 2 | gorontalo
# Processing Record 49 of Set 2 | hay river
# Processing Record 50 of Set 2 | saint-joseph
# Processing Record 1 of Set 3 | atuona
# Processing Record 2 of Set 3 | buala
# Processing Record 3 of Set 3 | sao filipe
# Processing Record 4 of Set 3 | sneek
# Processing Record 5 of Set 3 | nome
# Processing Record 6 of Set 3 | mayumba
# Processing Record 7 of Set 3 | constitucion
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | jacqueville
# Processing Record 10 of Set 3 | garowe
# Processing Record 11 of Set 3 | clyde river
# Processing Record 12 of Set 3 | hyeres
# Processing Record 13 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 3 | harper
# Processing Record 15 of Set 3 | rawson
# Processing Record 16 of Set 3 | aklavik
# Processing Record 17 of Set 3 | tonantins
# Processing Record 18 of Set 3 | inirida
# Processing Record 19 of Set 3 | trairi
# Processing Record 20 of Set 3 | hilo
# Processing Record 21 of Set 3 | opuwo
# Processing Record 22 of Set 3 | ponta do sol
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | saint george
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | namibe
# Processing Record 28 of Set 3 | iwanai
# Processing Record 29 of Set 3 | flinders
# Processing Record 30 of Set 3 | risor
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | southampton
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | huanren
# Processing Record 35 of Set 3 | union
# Processing Record 36 of Set 3 | liverpool
# Processing Record 37 of Set 3 | devonport
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | ixtapa
# Processing Record 40 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 3 | tazovskiy
# Processing Record 43 of Set 3 | nantucket
# Processing Record 44 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 3 | pakxan
# Processing Record 46 of Set 3 | necochea
# Processing Record 47 of Set 3 | dikson
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | kodiak
# Processing Record 50 of Set 3 | falun
# Processing Record 1 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 4 | salalah
# Processing Record 3 of Set 4 | angra
# City not found. Skipping...
# Processing Record 4 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 4 | mgandu
# Processing Record 6 of Set 4 | fortuna
# Processing Record 7 of Set 4 | caravelas
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | aykhal
# Processing Record 10 of Set 4 | port elizabeth
# Processing Record 11 of Set 4 | warwick
# Processing Record 12 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 4 | leningradskiy
# Processing Record 14 of Set 4 | haines junction
# Processing Record 15 of Set 4 | tairua
# Processing Record 16 of Set 4 | kapaa
# Processing Record 17 of Set 4 | talnakh
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | teguise
# Processing Record 20 of Set 4 | husavik
# Processing Record 21 of Set 4 | gat
# Processing Record 22 of Set 4 | victoria
# Processing Record 23 of Set 4 | georgetown
# Processing Record 24 of Set 4 | anadyr
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | chilliwack
# Processing Record 27 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 28 of Set 4 | lorengau
# Processing Record 29 of Set 4 | batemans bay
# Processing Record 30 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 4 | antofagasta
# Processing Record 32 of Set 4 | kashi
# Processing Record 33 of Set 4 | obo
# Processing Record 34 of Set 4 | biak
# Processing Record 35 of Set 4 | beringovskiy
# Processing Record 36 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 37 of Set 4 | wawa
# Processing Record 38 of Set 4 | murray bridge
# Processing Record 39 of Set 4 | tiebissou
# Processing Record 40 of Set 4 | vanimo
# Processing Record 41 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 4 | les cayes
# Processing Record 43 of Set 4 | pisco
# Processing Record 44 of Set 4 | ambilobe
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | codrington
# Processing Record 47 of Set 4 | yelizavetino
# Processing Record 48 of Set 4 | alta floresta
# Processing Record 49 of Set 4 | gilgit
# Processing Record 50 of Set 4 | esperance
# Processing Record 1 of Set 5 | yar-sale
# Processing Record 2 of Set 5 | concepcion
# Processing Record 3 of Set 5 | norman wells
# Processing Record 4 of Set 5 | bredasdorp
# Processing Record 5 of Set 5 | zalantun
# Processing Record 6 of Set 5 | byron bay
# Processing Record 7 of Set 5 | ancud
# Processing Record 8 of Set 5 | tunceli
# Processing Record 9 of Set 5 | lebu
# Processing Record 10 of Set 5 | torbay
# Processing Record 11 of Set 5 | chongwe
# Processing Record 12 of Set 5 | san pedro de lloc
# Processing Record 13 of Set 5 | adeje
# Processing Record 14 of Set 5 | fauske
# Processing Record 15 of Set 5 | half moon bay
# Processing Record 16 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 17 of Set 5 | miami
# Processing Record 18 of Set 5 | new norfolk
# Processing Record 19 of Set 5 | omboue
# Processing Record 20 of Set 5 | ndola
# Processing Record 21 of Set 5 | mahebourg
# Processing Record 22 of Set 5 | talcahuano
# Processing Record 23 of Set 5 | machali
# Processing Record 24 of Set 5 | russell
# Processing Record 25 of Set 5 | camana
# Processing Record 26 of Set 5 | banda aceh
# Processing Record 27 of Set 5 | tshikapa
# Processing Record 28 of Set 5 | orkney
# Processing Record 29 of Set 5 | mazyr
# Processing Record 30 of Set 5 | hithadhoo
# Processing Record 31 of Set 5 | watrous
# Processing Record 32 of Set 5 | rodrigues alves
# Processing Record 33 of Set 5 | cuyamel
# Processing Record 34 of Set 5 | nishihara
# Processing Record 35 of Set 5 | dalnerechensk
# Processing Record 36 of Set 5 | kalmunai
# Processing Record 37 of Set 5 | tocopilla
# Processing Record 38 of Set 5 | westport
# Processing Record 39 of Set 5 | kontagora
# Processing Record 40 of Set 5 | ust-tsilma
# Processing Record 41 of Set 5 | ozinki
# Processing Record 42 of Set 5 | vila velha
# Processing Record 43 of Set 5 | mugur-aksy
# Processing Record 44 of Set 5 | kayanga
# Processing Record 45 of Set 5 | dargaville
# Processing Record 46 of Set 5 | derzhavinsk
# Processing Record 47 of Set 5 | oudtshoorn
# Processing Record 48 of Set 5 | nianzishan
# Processing Record 49 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 5 | port-de-paix
# City not found. Skipping...
# Processing Record 1 of Set 6 | nabire
# Processing Record 2 of Set 6 | wajima
# Processing Record 3 of Set 6 | riyadh
# Processing Record 4 of Set 6 | oradea
# Processing Record 5 of Set 6 | balkhash
# Processing Record 6 of Set 6 | whitehorse
# Processing Record 7 of Set 6 | hasaki
# Processing Record 8 of Set 6 | grootfontein
# Processing Record 9 of Set 6 | rosarito
# Processing Record 10 of Set 6 | kudahuvadhoo
# Processing Record 11 of Set 6 | la palma
# Processing Record 12 of Set 6 | palauig
# Processing Record 13 of Set 6 | tilichiki
# Processing Record 14 of Set 6 | klaksvik
# Processing Record 15 of Set 6 | butaritari
# Processing Record 16 of Set 6 | bollene
# Processing Record 17 of Set 6 | inuvik
# Processing Record 18 of Set 6 | shiyan
# Processing Record 19 of Set 6 | farmington
# Processing Record 20 of Set 6 | champerico
# Processing Record 21 of Set 6 | salina
# Processing Record 22 of Set 6 | robe
# Processing Record 23 of Set 6 | guerrero negro
# Processing Record 24 of Set 6 | shingu
# Processing Record 25 of Set 6 | yamada
# Processing Record 26 of Set 6 | ho
# City not found. Skipping...
# Processing Record 27 of Set 6 | udon thani
# Processing Record 28 of Set 6 | lompoc
# Processing Record 29 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 6 | benguela
# Processing Record 31 of Set 6 | bathsheba
# Processing Record 32 of Set 6 | brazzaville
# Processing Record 33 of Set 6 | wamba
# Processing Record 34 of Set 6 | high rock
# Processing Record 35 of Set 6 | prabumulih
# Processing Record 36 of Set 6 | cidreira
# Processing Record 37 of Set 6 | koryazhma
# Processing Record 38 of Set 6 | balkanabat
# Processing Record 39 of Set 6 | sabya
# Processing Record 40 of Set 6 | pangai
# Processing Record 41 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 6 | lagoa
# Processing Record 43 of Set 6 | corralillo
# Processing Record 44 of Set 6 | quatre cocos
# Processing Record 45 of Set 6 | caluquembe
# Processing Record 46 of Set 6 | port keats
# Processing Record 47 of Set 6 | pauini
# Processing Record 48 of Set 6 | cabedelo
# Processing Record 49 of Set 6 | port arthur
# Processing Record 50 of Set 6 | asau
# Processing Record 1 of Set 7 | sabang
# Processing Record 2 of Set 7 | ilulissat
# Processing Record 3 of Set 7 | haimen
# Processing Record 4 of Set 7 | sao joao da barra
# Processing Record 5 of Set 7 | mazamari
# Processing Record 6 of Set 7 | valreas
# Processing Record 7 of Set 7 | sahuaripa
# Processing Record 8 of Set 7 | karpogory
# Processing Record 9 of Set 7 | ballangen
# Processing Record 10 of Set 7 | bergerac
# Processing Record 11 of Set 7 | marawi
# Processing Record 12 of Set 7 | buraydah
# Processing Record 13 of Set 7 | vestmanna
# Processing Record 14 of Set 7 | neuquen
# Processing Record 15 of Set 7 | nyzy
# Processing Record 16 of Set 7 | veraval
# Processing Record 17 of Set 7 | praia da vitoria
# Processing Record 18 of Set 7 | broken hill
# Processing Record 19 of Set 7 | kabanjahe
# Processing Record 20 of Set 7 | finspang
# Processing Record 21 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 7 | herat
# Processing Record 23 of Set 7 | muros
# Processing Record 24 of Set 7 | redcar
# Processing Record 25 of Set 7 | gulmarg
# Processing Record 26 of Set 7 | richards bay
# Processing Record 27 of Set 7 | ust-ilimsk
# Processing Record 28 of Set 7 | valparaiso
# Processing Record 29 of Set 7 | petatlan
# Processing Record 30 of Set 7 | egvekinot
# Processing Record 31 of Set 7 | myitkyina
# Processing Record 32 of Set 7 | burnie
# Processing Record 33 of Set 7 | mandera
# Processing Record 34 of Set 7 | belaya gora
# Processing Record 35 of Set 7 | gunnedah
# Processing Record 36 of Set 7 | benjamin constant
# Processing Record 37 of Set 7 | yagodnoye
# Processing Record 38 of Set 7 | porto nacional
# Processing Record 39 of Set 7 | bengkulu
# Processing Record 40 of Set 7 | saskylakh
# Processing Record 41 of Set 7 | tatvan
# Processing Record 42 of Set 7 | merritt island
# Processing Record 43 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 7 | tessalit
# Processing Record 45 of Set 7 | boddam
# Processing Record 46 of Set 7 | alberton
# Processing Record 47 of Set 7 | sinamar
# Processing Record 48 of Set 7 | laguna
# Processing Record 49 of Set 7 | siavonga
# Processing Record 50 of Set 7 | limbang
# Processing Record 1 of Set 8 | auki
# Processing Record 2 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 3 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 8 | san patricio
# Processing Record 5 of Set 8 | vao
# Processing Record 6 of Set 8 | los llanos de aridane
# Processing Record 7 of Set 8 | khatanga
# Processing Record 8 of Set 8 | amherst center
# Processing Record 9 of Set 8 | altrincham
# Processing Record 10 of Set 8 | coquimbo
# Processing Record 11 of Set 8 | abu samrah
# Processing Record 12 of Set 8 | lewistown
# Processing Record 13 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 8 | severomuysk
# Processing Record 15 of Set 8 | boueni
# Processing Record 16 of Set 8 | taybad
# Processing Record 17 of Set 8 | kaitangata
# City not found. Skipping...
# Processing Record 18 of Set 8 | tabou
# City not found. Skipping...
# Processing Record 19 of Set 8 | puerto cabezas
# City not found. Skipping...
# Processing Record 20 of Set 8 | tura
# City not found. Skipping...
# Processing Record 21 of Set 8 | suihua
# City not found. Skipping...
# Processing Record 22 of Set 8 | mirnyy
# City not found. Skipping...
# Processing Record 23 of Set 8 | te anau
# Processing Record 24 of Set 8 | madras
# Processing Record 25 of Set 8 | teya
# Processing Record 26 of Set 8 | weyburn
# Processing Record 27 of Set 8 | litovko
# Processing Record 28 of Set 8 | lucapa
# Processing Record 29 of Set 8 | bekhtery
# Processing Record 30 of Set 8 | ust-maya
# Processing Record 31 of Set 8 | kaeo
# Processing Record 32 of Set 8 | bereda
# Processing Record 33 of Set 8 | beidao
# Processing Record 34 of Set 8 | kavaratti
# Processing Record 35 of Set 8 | lom sak
# Processing Record 36 of Set 8 | bimbo
# Processing Record 37 of Set 8 | nemuro
# Processing Record 38 of Set 8 | antalaha
# Processing Record 39 of Set 8 | havre-saint-pierre
# Processing Record 40 of Set 8 | puerto del rosario
# Processing Record 41 of Set 8 | manado
# Processing Record 42 of Set 8 | kitimat
# Processing Record 43 of Set 8 | carlsbad
# Processing Record 44 of Set 8 | karratha
# Processing Record 45 of Set 8 | dalaba
# Processing Record 46 of Set 8 | seoul
# Processing Record 47 of Set 8 | katsuura
# Processing Record 48 of Set 8 | tirumullaivasal
# Processing Record 49 of Set 8 | catamarca
# Processing Record 50 of Set 8 | fairbanks
# Processing Record 1 of Set 9 | port pirie
# Processing Record 2 of Set 9 | pachino
# Processing Record 3 of Set 9 | jacareacanga
# Processing Record 4 of Set 9 | plettenberg bay
# Processing Record 5 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 6 of Set 9 | juneau
# Processing Record 7 of Set 9 | pacific grove
# Processing Record 8 of Set 9 | aksarka
# Processing Record 9 of Set 9 | dali
# Processing Record 10 of Set 9 | suntar
# Processing Record 11 of Set 9 | praia
# Processing Record 12 of Set 9 | grand gaube
# Processing Record 13 of Set 9 | japura
# Processing Record 14 of Set 9 | yeghegnavan
# Processing Record 15 of Set 9 | syracuse
# Processing Record 16 of Set 9 | kavieng
# Processing Record 17 of Set 9 | qafsah
# City not found. Skipping...
# Processing Record 18 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 9 | aleksandrov gay
# Processing Record 20 of Set 9 | mayo
# Processing Record 21 of Set 9 | alofi
# Processing Record 22 of Set 9 | manyana
# Processing Record 23 of Set 9 | havoysund
# Processing Record 24 of Set 9 | saint-francois
# Processing Record 25 of Set 9 | morgan city
# Processing Record 26 of Set 9 | yurino
# Processing Record 27 of Set 9 | camacari
# Processing Record 28 of Set 9 | hamilton
# Processing Record 29 of Set 9 | turtas
# Processing Record 30 of Set 9 | halifax
# Processing Record 31 of Set 9 | weligama
# Processing Record 32 of Set 9 | sivaki
# Processing Record 33 of Set 9 | pangnirtung
# Processing Record 34 of Set 9 | teahupoo
# Processing Record 35 of Set 9 | baykit
# Processing Record 36 of Set 9 | brigantine
# Processing Record 37 of Set 9 | bratsk
# Processing Record 38 of Set 9 | charagua
# Processing Record 39 of Set 9 | dingle
# Processing Record 40 of Set 9 | urucara
# Processing Record 41 of Set 9 | taguatinga
# Processing Record 42 of Set 9 | panindicuaro
# Processing Record 43 of Set 9 | le port
# Processing Record 44 of Set 9 | ampanihy
# Processing Record 45 of Set 9 | mezhdurechensk
# Processing Record 46 of Set 9 | kulhudhuffushi
# Processing Record 47 of Set 9 | sistranda
# Processing Record 48 of Set 9 | komsomolskiy
# Processing Record 49 of Set 9 | upernavik
# Processing Record 50 of Set 9 | basiawan
# Processing Record 1 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 2 of Set 10 | sussex
# Processing Record 3 of Set 10 | vila franca do campo
# Processing Record 4 of Set 10 | timmins
# Processing Record 5 of Set 10 | pangkalanbuun
# Processing Record 6 of Set 10 | santa cruz
# Processing Record 7 of Set 10 | fort frances
# Processing Record 8 of Set 10 | yerbogachen
# Processing Record 9 of Set 10 | praya
# Processing Record 10 of Set 10 | araouane
# Processing Record 11 of Set 10 | souillac
# Processing Record 12 of Set 10 | bac lieu
# Processing Record 13 of Set 10 | myaundzha
# Processing Record 14 of Set 10 | deputatskiy
# Processing Record 15 of Set 10 | verkhovazhye
# Processing Record 16 of Set 10 | zhezkazgan
# Processing Record 17 of Set 10 | isla vista
# Processing Record 18 of Set 10 | turan
# Processing Record 19 of Set 10 | vredendal
# Processing Record 20 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 21 of Set 10 | itaituba
# Processing Record 22 of Set 10 | la maddalena
# Processing Record 23 of Set 10 | riachao do jacuipe
# Processing Record 24 of Set 10 | shebalino
# Processing Record 25 of Set 10 | garoua
# Processing Record 26 of Set 10 | christchurch
# Processing Record 27 of Set 10 | marienburg
# Processing Record 28 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 30 of Set 10 | rocha
# Processing Record 31 of Set 10 | onega
# Processing Record 32 of Set 10 | tezu
# Processing Record 33 of Set 10 | castano primo
# Processing Record 34 of Set 10 | touros
# Processing Record 35 of Set 10 | doda
# Processing Record 36 of Set 10 | grindavik
# Processing Record 37 of Set 10 | saint-pierre
# Processing Record 38 of Set 10 | chapais
# Processing Record 39 of Set 10 | zhigansk
# Processing Record 40 of Set 10 | cockburn town
# Processing Record 41 of Set 10 | tianpeng
# Processing Record 42 of Set 10 | surt
# Processing Record 43 of Set 10 | broome
# Processing Record 44 of Set 10 | yulara
# Processing Record 45 of Set 10 | raudeberg
# Processing Record 46 of Set 10 | sept-iles
# Processing Record 47 of Set 10 | tanabe
# Processing Record 48 of Set 10 | calvinia
# Processing Record 49 of Set 10 | manacapuru
# Processing Record 50 of Set 10 | chuari khas
# Processing Record 1 of Set 11 | stolbishche
# Processing Record 2 of Set 11 | ha giang
# Processing Record 3 of Set 11 | lyngseidet
# Processing Record 4 of Set 11 | lavrentiya
# Processing Record 5 of Set 11 | taoudenni
# Processing Record 6 of Set 11 | akureyri
# Processing Record 7 of Set 11 | nouakchott
# Processing Record 8 of Set 11 | roxana
# Processing Record 9 of Set 11 | waitati
# Processing Record 10 of Set 11 | mahon
# Processing Record 11 of Set 11 | teguldet
# Processing Record 12 of Set 11 | pokhara
# Processing Record 13 of Set 11 | nelson bay
# Processing Record 14 of Set 11 | toamasina
# Processing Record 15 of Set 11 | channagiri
# Processing Record 16 of Set 11 | polovinnoye
# Processing Record 17 of Set 11 | mouzakion
# City not found. Skipping...
# Processing Record 18 of Set 11 | ambatofinandrahana
# Processing Record 19 of Set 11 | rena
# Processing Record 20 of Set 11 | kiruna
# Processing Record 21 of Set 11 | lamu
# Processing Record 22 of Set 11 | srednekolymsk
# Processing Record 23 of Set 11 | ulaanbaatar
# Processing Record 24 of Set 11 | najran
# Processing Record 25 of Set 11 | san jose
# Processing Record 26 of Set 11 | mandalgovi
# Processing Record 27 of Set 11 | bataipora
# Processing Record 28 of Set 11 | iranshahr
# Processing Record 29 of Set 11 | sorland
# Processing Record 30 of Set 11 | doha
# Processing Record 31 of Set 11 | merauke
# Processing Record 32 of Set 11 | storforshei
# Processing Record 33 of Set 11 | san quintin
# Processing Record 34 of Set 11 | bati
# Processing Record 35 of Set 11 | taltal
# Processing Record 36 of Set 11 | san policarpo
# Processing Record 37 of Set 11 | san luis
# Processing Record 38 of Set 11 | dombarovskiy
# Processing Record 39 of Set 11 | kathmandu
# Processing Record 40 of Set 11 | honiara
# Processing Record 41 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 11 | namatanai
# Processing Record 43 of Set 11 | narrabri
# Processing Record 44 of Set 11 | goundam
# Processing Record 45 of Set 11 | demba
# Processing Record 46 of Set 11 | puerto carreno
# Processing Record 47 of Set 11 | tuatapere
# Processing Record 48 of Set 11 | shakhunya
# Processing Record 49 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 11 | chimore
# Processing Record 1 of Set 12 | jimo
# Processing Record 2 of Set 12 | zatoka
# Processing Record 3 of Set 12 | kirakira
# Processing Record 4 of Set 12 | bucerias
# Processing Record 5 of Set 12 | bonthe
# Processing Record 6 of Set 12 | kropotkin
# Processing Record 7 of Set 12 | mezen
# Processing Record 8 of Set 12 | saldanha
# Processing Record 9 of Set 12 | cyangugu
# Processing Record 10 of Set 12 | puerto leguizamo
# Processing Record 11 of Set 12 | tashla
# Processing Record 12 of Set 12 | otavi
# Processing Record 13 of Set 12 | milkovo
# Processing Record 14 of Set 12 | abhar
# Processing Record 15 of Set 12 | north myrtle beach
# Processing Record 16 of Set 12 | uvat
# Processing Record 17 of Set 12 | urumqi
# Processing Record 18 of Set 12 | faanui
# Processing Record 19 of Set 12 | cao bang
# Processing Record 20 of Set 12 | blythe
# Processing Record 21 of Set 12 | noumea
# Processing Record 22 of Set 12 | santa isabel do rio negro
# Processing Record 23 of Set 12 | preobrazheniye
# Processing Record 24 of Set 12 | davenda
# Processing Record 25 of Set 12 | warri
# Processing Record 26 of Set 12 | nalut
# Processing Record 27 of Set 12 | horadiz
# Processing Record 28 of Set 12 | waingapu
# Processing Record 29 of Set 12 | hami
# Processing Record 30 of Set 12 | tayga
# Processing Record 31 of Set 12 | moyale
# Processing Record 32 of Set 12 | kushima
# Processing Record 33 of Set 12 | baniyas
# Processing Record 34 of Set 12 | sakakah
# Processing Record 35 of Set 12 | skovorodino
# Processing Record 36 of Set 12 | oranjemund
# Processing Record 37 of Set 12 | gumdag
# Processing Record 38 of Set 12 | luderitz
# Processing Record 39 of Set 12 | bundaberg
# Processing Record 40 of Set 12 | necaxa
# Processing Record 41 of Set 12 | salgueiro
# Processing Record 42 of Set 12 | fare
# Processing Record 43 of Set 12 | adrar
# Processing Record 44 of Set 12 | whitley bay
# Processing Record 45 of Set 12 | tsevie
# Processing Record 46 of Set 12 | pelym
# Processing Record 47 of Set 12 | vagur
# Processing Record 48 of Set 12 | yanam
# Processing Record 49 of Set 12 | altoona
# Processing Record 50 of Set 12 | minot
# Processing Record 1 of Set 13 | benicarlo
# Processing Record 2 of Set 13 | lixourion
# Processing Record 3 of Set 13 | dunedin
# Processing Record 4 of Set 13 | coos bay
# Processing Record 5 of Set 13 | kolpashevo
# Processing Record 6 of Set 13 | orlik
# Processing Record 7 of Set 13 | baruun-urt
# Processing Record 8 of Set 13 | oktyabrskoye
# Processing Record 9 of Set 13 | palmer
# Processing Record 10 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 11 of Set 13 | kargil
# Processing Record 12 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 13 | katghora
# Processing Record 15 of Set 13 | oussouye
# Processing Record 16 of Set 13 | tecolutla
# Processing Record 17 of Set 13 | nanchong
# Processing Record 18 of Set 13 | chabahar
# Processing Record 19 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | berdigestyakh
# Processing Record 21 of Set 13 | gornopravdinsk
# Processing Record 22 of Set 13 | alfredo chaves
# Processing Record 23 of Set 13 | lata
# Processing Record 24 of Set 13 | zvishavane
# Processing Record 25 of Set 13 | odweyne
# Processing Record 26 of Set 13 | bentiu
# Processing Record 27 of Set 13 | mina
# Processing Record 28 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 13 | shizunai
# Processing Record 30 of Set 13 | paamiut
# Processing Record 31 of Set 13 | severo-kurilsk
# Processing Record 32 of Set 13 | lumeje
# Processing Record 33 of Set 13 | charters towers
# Processing Record 34 of Set 13 | asfi
# Processing Record 35 of Set 13 | saint-augustin
# Processing Record 36 of Set 13 | grand forks
# Processing Record 37 of Set 13 | abatskoye
# Processing Record 38 of Set 13 | padang
# Processing Record 39 of Set 13 | granadilla de abona
# Processing Record 40 of Set 13 | inndyr
# Processing Record 41 of Set 13 | boffa
# Processing Record 42 of Set 13 | mahajanga
# Processing Record 43 of Set 13 | yenagoa
# Processing Record 44 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 13 | camacha
# Processing Record 46 of Set 13 | eskil
# Processing Record 47 of Set 13 | biltine
# Processing Record 48 of Set 13 | vangaindrano
# Processing Record 49 of Set 13 | tamandare
# Processing Record 50 of Set 13 | oulainen
# Processing Record 1 of Set 14 | tuburan
# Processing Record 2 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 3 of Set 14 | cortez
# Processing Record 4 of Set 14 | zarand
# Processing Record 5 of Set 14 | concordia
# Processing Record 6 of Set 14 | livramento
# Processing Record 7 of Set 14 | miram shah
# Processing Record 8 of Set 14 | awbari
# Processing Record 9 of Set 14 | gondanglegi
# Processing Record 10 of Set 14 | forbes
# Processing Record 11 of Set 14 | djibo
# Processing Record 12 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 13 of Set 14 | afonso bezerra
# Processing Record 14 of Set 14 | coihaique
# Processing Record 15 of Set 14 | moron
# Processing Record 16 of Set 14 | katangli
# Processing Record 17 of Set 14 | greenville
# Processing Record 18 of Set 14 | maragogi
# Processing Record 19 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 20 of Set 14 | bathurst
# Processing Record 21 of Set 14 | shitanjing
# Processing Record 22 of Set 14 | igarka
# Processing Record 23 of Set 14 | sabzevar
# Processing Record 24 of Set 14 | keetmanshoop
# Processing Record 25 of Set 14 | dzhebariki-khaya
# Processing Record 26 of Set 14 | tarauaca
# Processing Record 27 of Set 14 | baiao
# Processing Record 28 of Set 14 | usinsk
# Processing Record 29 of Set 14 | north bend
# Processing Record 30 of Set 14 | malakal
# Processing Record 31 of Set 14 | barra do garcas
# Processing Record 32 of Set 14 | concarneau
# Processing Record 33 of Set 14 | kaka
# Processing Record 34 of Set 14 | devils lake
# Processing Record 35 of Set 14 | dusi
# Processing Record 36 of Set 14 | san cristobal
# Processing Record 37 of Set 14 | kyaka
# Processing Record 38 of Set 14 | vilhena
# Processing Record 39 of Set 14 | kansanshi
# Processing Record 40 of Set 14 | la ronge
# Processing Record 41 of Set 14 | rodino
# Processing Record 42 of Set 14 | shagamu
# Processing Record 43 of Set 14 | kununurra
# Processing Record 44 of Set 14 | port macquarie
# Processing Record 45 of Set 14 | valdivia
# Processing Record 46 of Set 14 | roma
# Processing Record 47 of Set 14 | lodja
# Processing Record 48 of Set 14 | kahului
# Processing Record 49 of Set 14 | wanaka
# Processing Record 50 of Set 14 | punta alta
# Processing Record 1 of Set 15 | ganzhou
# Processing Record 2 of Set 15 | snezhnogorsk
# Processing Record 3 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 4 of Set 15 | kruisfontein
# Processing Record 5 of Set 15 | akyab
# Processing Record 6 of Set 15 | santiago del estero
# Processing Record 7 of Set 15 | stanisic
# Processing Record 8 of Set 15 | bairiki
# Processing Record 9 of Set 15 | neiafu
# Processing Record 10 of Set 15 | mananara
# Processing Record 11 of Set 15 | akdepe
# Processing Record 12 of Set 15 | alice town
# Processing Record 13 of Set 15 | manggar
# Processing Record 14 of Set 15 | lakewood
# Processing Record 15 of Set 15 | sao gabriel da cachoeira
# Processing Record 16 of Set 15 | acarau
# Processing Record 17 of Set 15 | bombay
# Processing Record 18 of Set 15 | viedma
# Processing Record 19 of Set 15 | ponta delgada
# Processing Record 20 of Set 15 | madimba
# Processing Record 21 of Set 15 | ornskoldsvik
# Processing Record 22 of Set 15 | floresta
# Processing Record 23 of Set 15 | effingham
# Processing Record 24 of Set 15 | romitan
# Processing Record 25 of Set 15 | bud
# Processing Record 26 of Set 15 | mokrous
# Processing Record 27 of Set 15 | manta
# Processing Record 28 of Set 15 | kasongo-lunda
# Processing Record 29 of Set 15 | leeds
# Processing Record 30 of Set 15 | goya
# Processing Record 31 of Set 15 | manuel doblado
# City not found. Skipping...
# Processing Record 32 of Set 15 | rio grande
# Processing Record 33 of Set 15 | puerto quijarro
# Processing Record 34 of Set 15 | mandurah
# Processing Record 35 of Set 15 | innisfail
# Processing Record 36 of Set 15 | hwange
# Processing Record 37 of Set 15 | gwembe
# Processing Record 38 of Set 15 | kokopo
# Processing Record 39 of Set 15 | mumford
# Processing Record 40 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 15 | luwingu
# Processing Record 42 of Set 15 | svirstroy
# Processing Record 43 of Set 15 | cuamba
# Processing Record 44 of Set 15 | manjacaze
# Processing Record 45 of Set 15 | blackpool
# Processing Record 46 of Set 15 | golden
# Processing Record 47 of Set 15 | venado tuerto
# Processing Record 48 of Set 15 | tukrah
# Processing Record 49 of Set 15 | mangile
# City not found. Skipping...
# Processing Record 50 of Set 15 | sibu
# Processing Record 1 of Set 16 | bubaque
# Processing Record 2 of Set 16 | sao jose da coroa grande
# Processing Record 3 of Set 16 | tornio
# Processing Record 4 of Set 16 | ormara
# Processing Record 5 of Set 16 | altay
# Processing Record 6 of Set 16 | kenora
# Processing Record 7 of Set 16 | corinto
# Processing Record 8 of Set 16 | arkhipo-osipovka
# Processing Record 9 of Set 16 | harrisburg
# Processing Record 10 of Set 16 | yekaterinovka
# Processing Record 11 of Set 16 | rincon
# Processing Record 12 of Set 16 | arman
# Processing Record 13 of Set 16 | bamiantong
# Processing Record 14 of Set 16 | sulangan
# Processing Record 15 of Set 16 | kasama
# Processing Record 16 of Set 16 | mama
# Processing Record 17 of Set 16 | seguin
# Processing Record 18 of Set 16 | torit
# Processing Record 19 of Set 16 | sierra vista
# Processing Record 20 of Set 16 | bluefield
# Processing Record 21 of Set 16 | sambava
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 709

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cape Town      ZA -33.9258   18.4232     72.12        67          20
# 1          Castro      BR -24.7911  -50.0119     62.37        99          67
# 2       Boa Vista      BR   2.8197  -60.6733     75.18        83          75
# 3       Kastamonu      TR  41.5000   33.6667     41.02        97         100
# 4      Oranjestad      AW  12.5240  -70.0270     78.91        86          20
# ..            ...     ...      ...       ...       ...       ...         ...
# 704        Seguin      US  29.5688  -97.9647     46.72        60           0
# 705         Torit      SS   4.4133   32.5678     80.80        27          95
# 706  Sierra Vista      US  31.5545 -110.3037     55.85        25           0
# 707     Bluefield      US  37.2698  -81.2223     27.52        93          11
# 708       Sambava      MG -14.2667   50.1667     81.61        59           2
#
#      Wind Speed Current Description
# 0          5.75          few clouds
# 1          6.46       broken clouds
# 2          1.14       broken clouds
# 3          4.14     overcast clouds
# 4         14.97          few clouds
# ..          ...                 ...
# 704        8.05           clear sky
# 705        4.25     overcast clouds
# 706       12.66           clear sky
# 707        2.48          few clouds
# 708        9.28           clear sky
#
# [709 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
